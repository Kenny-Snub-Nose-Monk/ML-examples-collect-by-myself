# %% [markdown]
# ## (****) Setup Python Training Environment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pylab as plts
import math

from scipy import stats

# %matplotlib inline

# %% [markdown]
# ## (****) Read file from Google Drive

# %%
# Read file from Google Drive

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ## (****) Read CMP csv file

# %% [markdown]
# filename : G11-1-AC(7X15)20160126-002Export
#
# groupid : G11
#
# eqpid : AC(7X15)
#
# date : 20160126
#
# sno : 002
#
# ptcno : PTC5
#
# tempunit : Deg.F
#
# datapoint : 1
#
# datavalue : 90.6

# %% [markdown]
# ### G11

# %%
fp = pd.read_csv('/content/gdrive/My Drive/thubigdata2019/training230/G11/G11-1-AC(7X15)20160706-001_Export.txt',sep="\t")
#print(fp)

fp = fp.drop([0])
fp = fp.drop(columns=['Unnamed: 6'])
fp = fp.apply(pd.to_numeric, errors='coerce')

fp.columns
# Out:
# Index(['G11-PTC10  ', 'G11-PTC11  ', 'G11-PTC12  ', 'G11-PTC13  ',
#        'G11-PTC14  ', 'G11-PTC15  '],
#       dtype='object')

# %%
fp.describe()
# Out:
#        G11-PTC10    G11-PTC11    ...  G11-PTC14    G11-PTC15
# count   314.000000   314.000000  ...   314.000000   314.000000
# mean    273.831529   275.299045  ...   280.642357   278.898408
# std      88.521391    92.268717  ...    95.279623    96.348909
# min      78.200000    78.300000  ...    81.000000    79.900000
# 25%     198.050000   194.475000  ...   199.075000   196.250000
# 50%     320.800000   330.100000  ...   350.800000   351.050000
# 75%     348.075000   351.075000  ...   354.500000   353.500000
# max     352.100000   353.700000  ...   354.800000   354.400000
#
# [8 rows x 6 columns]

# %%
# Draw Plot
plt.figure(figsize=(10,6), dpi= 80)
plt.plot('G11-PTC10  ', data=fp, color='r')
plt.plot('G11-PTC11  ', data=fp, color='b')
plt.plot('G11-PTC12  ', data=fp, color='g')
plt.plot('G11-PTC13  ', data=fp, color='y')
plt.plot('G11-PTC14  ', data=fp, color='m')
plt.plot('G11-PTC15  ', data=fp, color='c')
plt.show()

# %% [markdown]
# ### G11 (2)

# %%
fp = pd.read_csv('/content/gdrive/My Drive/thubigdata2019/training230/G11/G11-1-AC(7x15)20160518-004_Export.txt',sep="\t")
#print(fp)

fp.columns
# Out:
# Index(['G11-PTC9  ', 'G11-PTC10  ', 'G11-PTC11  ', 'G11-PTC12  ',
#        'G11-PTC14  ', 'Unnamed: 5'],
#       dtype='object')

# %%
fp = fp.drop([0])
fp = fp.drop(columns=['Unnamed: 5'])
fp = fp.apply(pd.to_numeric, errors='coerce')
fp.describe()
# Out:
#        G11-PTC9    G11-PTC10    G11-PTC11    G11-PTC12    G11-PTC14
# count  245.000000   245.000000   245.000000   245.000000   245.000000
# mean   273.602041   276.644898   274.302041   274.117143   273.289388
# std     92.030785    93.139695    92.907570    93.958233    93.159250
# min     76.100000    75.700000    76.300000    76.500000    76.500000
# 25%    198.500000   198.700000   195.800000   195.500000   193.600000
# 50%    322.500000   330.200000   325.700000   326.700000   324.100000
# 75%    353.100000   354.500000   354.100000   354.300000   353.700000
# max    354.400000   354.900000   354.500000   354.800000   354.900000

# %%
# Draw Plot
plt.figure(figsize=(10,6), dpi= 80)
plt.plot('G11-PTC9  ', data=fp, color='c')
plt.plot('G11-PTC10  ', data=fp, color='r')
plt.plot('G11-PTC11  ', data=fp, color='b')
plt.plot('G11-PTC12  ', data=fp, color='g')
plt.plot('G11-PTC14  ', data=fp, color='m')

plt.show()

# %% [markdown]
# ### G15

# %%
fp = pd.read_csv('/content/gdrive/My Drive/thubigdata2019/training230/G15/G15-AC(12X30)20160628-003_Export.txt',sep="\t")
#print(fp)

fp.columns
# Out:
# Index(['G15-PTC1  ', 'G15-PTC3  ', 'G15-PTC6  ', 'G15-PTC29  ', 'G15-PTC30  ',
#        'G15-PTC31  ', 'G15-PTC32  ', 'G15-PTC39  ', 'Unnamed: 8'],
#       dtype='object')

# %%
fp = fp.drop([0])
fp = fp.drop(columns=['Unnamed: 8'])
fp = fp.apply(pd.to_numeric, errors='coerce')
fp.describe()
# Out:
#        G15-PTC1    G15-PTC3    ...  G15-PTC32    G15-PTC39
# count  244.000000  244.000000  ...   244.000000   244.000000
# mean   216.357787  217.910246  ...   216.109426   217.986475
# std     63.565002   60.670990  ...    63.399462    61.817937
# min     82.400000   83.300000  ...    84.900000    86.300000
# 25%    159.300000  164.300000  ...   158.650000   160.625000
# 50%    248.400000  245.650000  ...   246.950000   249.400000
# 75%    272.925000  272.450000  ...   273.300000   273.325000
# max    274.300000  274.700000  ...   274.200000   274.300000
#
# [8 rows x 8 columns]

# %%
# Draw Plot
plt.figure(figsize=(10,6), dpi= 80)
plt.plot('G15-PTC1  ', data=fp, color='c')
plt.plot('G15-PTC3  ', data=fp, color='r')
plt.plot('G15-PTC6  ', data=fp, color='b')
plt.plot('G15-PTC29  ', data=fp, color='g')
plt.plot('G15-PTC30  ', data=fp, color='b')
plt.plot('G15-PTC31  ', data=fp, color='m')
plt.plot('G15-PTC32  ', data=fp, color='y')
plt.plot('G15-PTC39  ', data=fp, color='m')
plt.show()

# %% [markdown]
# ### G15 (2)

# %%
fp = pd.read_csv('/content/gdrive/My Drive/thubigdata2019/training230/G15/G15-AC(7X15)20170104-003_Export.txt',sep="\t")
#print(fp)

fp.columns
# Out:
# Index(['G15-PTC7  ', 'G15-PTC9  ', 'G15-PTC10  ', 'G15-PTC11  ', 'G15-PTC12  ',
#        'Unnamed: 5'],
#       dtype='object')

# %%
fp = fp.drop([0])
fp = fp.drop(columns=['Unnamed: 5'])
fp = fp.apply(pd.to_numeric, errors='coerce')
fp.describe()
# Out:
#        G15-PTC7    G15-PTC9    G15-PTC10    G15-PTC11    G15-PTC12
# count  178.000000  178.000000   178.000000   178.000000   178.000000
# mean   218.052809  216.362921   216.296067   216.524157   218.515730
# std     65.425589   65.911609    66.086466    65.394158    65.915272
# min     72.700000   73.000000    72.900000    73.600000    72.400000
# 25%    167.350000  166.025000   166.625000   166.250000   166.775000
# 50%    256.000000  253.000000   252.600000   252.500000   259.650000
# 75%    271.900000  271.400000   271.500000   271.300000   271.600000
# max    272.200000  271.800000   272.100000   271.900000   272.400000

# %%
# Draw Plot
plt.figure(figsize=(10,6), dpi= 80)
plt.plot('G15-PTC7  ', data=fp, color='c')
plt.plot('G15-PTC9  ', data=fp, color='r')
plt.plot('G15-PTC10  ', data=fp, color='b')
plt.plot('G15-PTC11  ', data=fp, color='g')
plt.plot('G15-PTC12  ', data=fp, color='b')
plt.show()

# %% [markdown]
# ### G17

# %%
fp = pd.read_csv('/content/gdrive/My Drive/thubigdata2019/training230/G17/G17-AC(7X15)20170327-001_Export.txt',sep="\t")
#print(fp)

fp.columns
# Out:
# Index(['G17-PTC7  ', 'G17-PTC9  ', 'G17-PTC10  ', 'G17-PTC11  ', 'G17-PTC12  ',
#        'G17-PTC14  ', 'G17-PTC15  ', 'G17-PTC16  ', 'Unnamed: 8'],
#       dtype='object')

# %%
fp = fp.drop([0])
fp = fp.drop(columns=['Unnamed: 8'])
fp = fp.apply(pd.to_numeric, errors='coerce')
fp.describe()
# Out:
#        G17-PTC7    G17-PTC9    ...  G17-PTC15    G17-PTC16
# count  302.000000  302.000000  ...   302.000000   302.000000
# mean   206.119536  205.221523  ...   200.778808   207.168874
# std     58.345015   56.118024  ...    57.242201    58.783337
# min     70.000000   69.800000  ...    69.600000    71.100000
# 25%    161.425000  168.150000  ...   167.075000   160.325000
# 50%    230.650000  226.750000  ...   220.900000   232.400000
# 75%    255.875000  253.475000  ...   249.600000   256.675000
# max    257.500000  257.000000  ...   255.700000   258.700000
#
# [8 rows x 8 columns]

# %%
# Draw Plot
plt.figure(figsize=(10,6), dpi= 80)
plt.plot('G17-PTC7  ', data=fp, color='c')
plt.plot('G17-PTC9  ', data=fp, color='r')
plt.plot('G17-PTC10  ', data=fp, color='b')
plt.plot('G17-PTC11  ', data=fp, color='g')
plt.plot('G17-PTC12  ', data=fp, color='b')
plt.plot('G17-PTC14  ', data=fp, color='m')
plt.plot('G17-PTC15  ', data=fp, color='y')
plt.plot('G17-PTC16  ', data=fp, color='m')
plt.show()

# %% [markdown]
# ### G17 (2)

# %%
fp = pd.read_csv('/content/gdrive/My Drive/thubigdata2019/training230/G17/G17-AC(7x15)20160527-005_Export.txt',sep="\t")
#print(fp)

fp.columns
# Out:
# Index(['G17-PTC10  ', 'G17-PTC11  ', 'G17-PTC12  ', 'G17-PTC13  ',
#        'G17-PTC14  ', 'G17-PTC15  ', 'G17-PTC16  ', 'G17-PTC18  ',
#        'Unnamed: 8'],
#       dtype='object')

# %%
fp = fp.drop([0])
fp = fp.drop(columns=['Unnamed: 8'])
fp = fp.apply(pd.to_numeric, errors='coerce')
fp.describe()
# Out:
#        G17-PTC10    G17-PTC11    ...  G17-PTC16    G17-PTC18
# count   308.000000   308.000000  ...   308.000000   308.000000
# mean    205.749026   205.435714  ...   206.953571   202.226948
# std      57.940287    55.814376  ...    59.173039    56.792296
# min      75.600000    75.700000  ...    78.000000    75.400000
# 25%     155.875000   162.375000  ...   154.300000   166.575000
# 50%     231.450000   227.550000  ...   234.000000   222.300000
# 75%     256.300000   254.450000  ...   258.025000   251.425000
# max     257.800000   257.400000  ...   258.900000   257.700000
#
# [8 rows x 8 columns]

# %%
# Draw Plot
plt.figure(figsize=(10,6), dpi= 80)
plt.plot('G17-PTC10  ', data=fp, color='c')
plt.plot('G17-PTC11  ', data=fp, color='r')
plt.plot('G17-PTC12  ', data=fp, color='b')
plt.plot('G17-PTC13  ', data=fp, color='g')
plt.plot('G17-PTC14  ', data=fp, color='b')
plt.plot('G17-PTC15  ', data=fp, color='m')
plt.plot('G17-PTC16  ', data=fp, color='y')
plt.plot('G17-PTC18  ', data=fp, color='m')
plt.show()

# %% [markdown]
# ### G19

# %%
fp = pd.read_csv('/content/gdrive/My Drive/thubigdata2019/training230/G19/G19-AC(12X30)20170511-002_Export.txt',sep="\t")
#print(fp)

fp.columns
# Out:
# Index(['G19-PTC3  ', 'G19-PTC9  ', 'G19-PTC30  ', 'G19-PTC31  ', 'G19-PTC35  ',
#        'G19-PTC38  ', 'G19-PTC42  ', 'G19-PTC44  ', 'Unnamed: 8'],
#       dtype='object')

# %%
fp = fp.drop([0])
fp = fp.drop(columns=['Unnamed: 8'])
fp = fp.apply(pd.to_numeric, errors='coerce')
fp.describe()
# Out:
#        G19-PTC3    G19-PTC9    ...  G19-PTC42    G19-PTC44
# count  268.000000  268.000000  ...   268.000000   268.000000
# mean   210.701493  209.827985  ...   211.253358   203.145522
# std     52.537552   52.422121  ...    54.060830    52.241597
# min     88.700000   88.100000  ...    89.800000    81.300000
# 25%    164.950000  165.775000  ...   162.775000   163.725000
# 50%    243.350000  241.500000  ...   248.800000   227.950000
# 75%    252.700000  252.125000  ...   253.100000   247.600000
# max    253.500000  252.700000  ...   253.700000   249.800000
#
# [8 rows x 8 columns]

# %%
# Draw Plot
plt.figure(figsize=(10,6), dpi= 80)
plt.plot('G19-PTC3  ', data=fp, color='c')
plt.plot('G19-PTC9  ', data=fp, color='r')
plt.plot('G19-PTC30  ', data=fp, color='b')
plt.plot('G19-PTC31  ', data=fp, color='g')
plt.plot('G19-PTC35  ', data=fp, color='b')
plt.plot('G19-PTC38  ', data=fp, color='m')
plt.plot('G19-PTC42  ', data=fp, color='y')
plt.plot('G19-PTC44  ', data=fp, color='m')
plt.show()

# %% [markdown]
# ### G32

# %%
fp = pd.read_csv('/content/gdrive/My Drive/thubigdata2019/training230/G32/G32-AC(12X30)20170505-002_Export.txt',sep="\t")
#print(fp)

fp.columns
# Out:
# Index(['G32-PTC2  ', 'G32-PTC3  ', 'G32-PTC4  ', 'G32-PTC11  ', 'G32-PTC12  ',
#        'G32-PTC16  ', 'G32-PTC17  ', 'G32-PTC44  ', 'Unnamed: 8'],
#       dtype='object')

# %%
fp = fp.drop([0])
fp = fp.drop(columns=['Unnamed: 8'])
fp = fp.apply(pd.to_numeric, errors='coerce')
fp.describe()
# Out:
#        G32-PTC2    G32-PTC3    ...  G32-PTC17    G32-PTC44
# count  327.000000  327.000000  ...   327.000000   327.000000
# mean   269.167584  261.470948  ...   271.929969   270.131498
# std     95.568953  104.104885  ...    92.512751    94.567166
# min     76.400000    0.000000  ...    81.000000    81.900000
# 25%    180.400000  166.700000  ...   183.550000   176.150000
# 50%    318.600000  310.400000  ...   321.000000   323.000000
# 75%    353.050000  353.800000  ...   351.500000   350.200000
# max    353.600000  354.400000  ...   352.000000   350.900000
#
# [8 rows x 8 columns]

# %%
# Draw Plot
plt.figure(figsize=(10,6), dpi= 80)
plt.plot('G32-PTC2  ', data=fp, color='c')
plt.plot('G32-PTC3  ', data=fp, color='r')
plt.plot('G32-PTC4  ', data=fp, color='b')
plt.plot('G32-PTC11  ', data=fp, color='g')
plt.plot('G32-PTC12  ', data=fp, color='b')
plt.plot('G32-PTC16  ', data=fp, color='m')
plt.plot('G32-PTC17  ', data=fp, color='y')
plt.plot('G32-PTC44  ', data=fp, color='m')
plt.show()

# %% [markdown]
# ### G34

# %%
fp = pd.read_csv('/content/gdrive/My Drive/thubigdata2019/training230/G34/G34-AC(12X30)20190328-002_Export.txt',sep="\t")
#print(fp)

fp.columns
# Out:
# Index(['G34-PTC1  ', 'G34-PTC3  ', 'G34-PTC6  ', 'G34-PTC16  ', 'G34-PTC18  ',
#        'G34-PTC20  ', 'G34-PTC26  ', 'G34-PTC45  ', 'Unnamed: 8'],
#       dtype='object')

# %%
fp = fp.drop([0])
fp = fp.drop(columns=['Unnamed: 8'])
fp = fp.apply(pd.to_numeric, errors='coerce')
fp.describe()
# Out:
#        G34-PTC1    G34-PTC3    ...  G34-PTC26    G34-PTC45
# count  326.000000  326.000000  ...   326.000000   326.000000
# mean   188.043865  188.555521  ...   188.032515   189.161963
# std     69.556052   69.559322  ...    69.027682    69.283353
# min     73.700000   74.400000  ...    72.800000    75.000000
# 25%    123.700000  123.325000  ...   124.450000   118.375000
# 50%    201.200000  202.300000  ...   201.250000   206.800000
# 75%    259.725000  260.025000  ...   259.175000   260.400000
# max    264.100000  264.200000  ...   263.900000   262.100000
#
# [8 rows x 8 columns]

# %%
# Draw Plot
plt.figure(figsize=(10,6), dpi= 80)
plt.plot('G34-PTC1  ', data=fp, color='c')
plt.plot('G34-PTC3  ', data=fp, color='r')
plt.plot('G34-PTC6  ', data=fp, color='b')
plt.plot('G34-PTC16  ', data=fp, color='g')
plt.plot('G34-PTC18  ', data=fp, color='b')
plt.plot('G34-PTC20  ', data=fp, color='m')
plt.plot('G34-PTC26  ', data=fp, color='y')
plt.plot('G34-PTC45  ', data=fp, color='m')
plt.show()

# %% [markdown]
# ### G48

# %%
fp = pd.read_csv('/content/gdrive/My Drive/thubigdata2019/training230/G48/G48-AC(12X30)20160413-003_Export.txt',sep="\t")
#print(fp)

fp.columns
# Out:
# Index(['G48-PTC1  ', 'G48-PTC2  ', 'G48-PTC8  ', 'G48-PTC11  ', 'G48-PTC26  ',
#        'G48-PTC28  ', 'G48-PTC33  ', 'G48-PTC34  ', 'Unnamed: 8'],
#       dtype='object')

# %%
fp = fp.drop([0])
fp = fp.drop(columns=['Unnamed: 8'])
fp = fp.apply(pd.to_numeric, errors='coerce')
fp.describe()
# Out:
#        G48-PTC1    G48-PTC2    ...  G48-PTC33    G48-PTC34
# count  380.000000  380.000000  ...   380.000000   380.000000
# mean   204.385000  204.987105  ...   200.549211   202.538158
# std     63.588552   63.433901  ...    61.618995    60.971626
# min     70.800000   71.400000  ...    73.100000    73.700000
# 25%    154.300000  155.175000  ...   157.575000   164.350000
# 50%    229.350000  230.000000  ...   220.550000   221.650000
# 75%    261.925000  262.300000  ...   256.300000   256.250000
# max    265.800000  266.100000  ...   264.700000   265.200000
#
# [8 rows x 8 columns]

# %%
# Draw Plot
plt.figure(figsize=(10,6), dpi= 80)
plt.plot('G48-PTC1  ', data=fp, color='c')
plt.plot('G48-PTC2  ', data=fp, color='r')
plt.plot('G48-PTC8  ', data=fp, color='b')
plt.plot('G48-PTC11  ', data=fp, color='g')
plt.plot('G48-PTC26  ', data=fp, color='b')
plt.plot('G48-PTC28  ', data=fp, color='m')
plt.plot('G48-PTC33  ', data=fp, color='y')
plt.plot('G48-PTC34  ', data=fp, color='m')
plt.show()

# %% [markdown]
# ### G49

# %%
fp = pd.read_csv('/content/gdrive/My Drive/thubigdata2019/training230/G49/G49-AC(12x30)20190417-001_Export.txt',sep="\t")
#print(fp)

fp.columns
# Out:
# Index(['G49-PTC9  ', 'G49-PTC18  ', 'G49-PTC20  ', 'G49-PTC31  ',
#        'G49-PTC34  ', 'G49-PTC36  ', 'G49-PTC40  ', 'G49-PTC47  ',
#        'Unnamed: 8'],
#       dtype='object')

# %%
fp = fp.drop([0])
fp = fp.drop(columns=['Unnamed: 8'])
fp = fp.apply(pd.to_numeric, errors='coerce')
fp.describe()
# Out:
#        G49-PTC9    G49-PTC18    ...  G49-PTC40    G49-PTC47
# count  386.000000   386.000000  ...   386.000000   386.000000
# mean   257.653627   257.453368  ...   257.368394   255.725130
# std    100.606925   100.582339  ...   100.390521   100.127568
# min     70.900000    71.700000  ...    72.000000    68.500000
# 25%    164.525000   164.425000  ...   164.950000   165.350000
# 50%    307.200000   305.650000  ...   305.700000   303.200000
# 75%    351.300000   351.375000  ...   350.300000   348.775000
# max    352.200000   352.500000  ...   350.900000   350.000000
#
# [8 rows x 8 columns]

# %%
# Draw Plot
plt.figure(figsize=(10,6), dpi= 80)
plt.plot('G49-PTC9  ', data=fp, color='c')
plt.plot('G49-PTC18  ', data=fp, color='r')
plt.plot('G49-PTC20  ', data=fp, color='b')
plt.plot('G49-PTC31  ', data=fp, color='g')
plt.plot('G49-PTC34  ', data=fp, color='b')
plt.plot('G49-PTC36  ', data=fp, color='m')
plt.plot('G49-PTC40  ', data=fp, color='y')
plt.plot('G49-PTC47  ', data=fp, color='m')
plt.show()
